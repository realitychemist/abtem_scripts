# %%
import matplotlib.pyplot as plt
import cmasher
import graphical

# %%
count_array_2nm = [[4, 4, 3, 1, 1, 3, 1, 3, 0],
                   [1, 4, 0, 2, 1, 3 ,1, 2, 0],
                   [3, 3, 3, 0, 0, 2, 3, 4, 1],
                   [0, 2, 3, 4, 5, 3, 5, 3, 3],
                   [4, 3, 2, 5, 3, 3, 2, 2, 1],
                   [0, 1, 0, 4, 3, 4, 2, 1, 2],
                   [1, 3, 2, 1, 4, 2, 0, 1, 4],
                   [1, 2, 4, 3, 2, 2, 2, 2, 3],
                   [2, 2, 0, 4, 2, 2, 0, 3, 3]]
plt.imshow(count_array_2nm, cmap="cmr.amber")
plt.savefig(graphical.gui_get_path(is_file=False)/"count_map_2nm.png")

# %%
count_array_4nm = [[4, 5, 3, 2, 2, 3, 3, 5, 5],
                   [5, 3, 4, 4, 4, 2, 1, 2, 5],
                   [2, 6, 6, 5, 5, 5, 4, 4, 8],
                   [4, 6, 3, 7, 5, 6, 5, 3, 3],
                   [4, 4, 7, 6, 6, 4, 4, 2, 4],
                   [2, 6, 4, 5, 5, 7, 3, 9, 6],
                   [4, 1, 6, 5, 3, 3, 1, 4, 4],
                   [2, 4, 4, 5, 3, 6, 7, 1, 2],
                   [4, 3, 5, 5, 3, 5, 2, 2, 6]]
plt.imshow(count_array_4nm, cmap="cmr.amber")
plt.savefig(graphical.gui_get_path(is_file=False)/"count_map_4nm.png")

# %%
count_array_28nm = [[31, 21, 28, 30, 27, 29, 28, 29, 23],
                    [24, 31, 31, 35, 22, 25, 28, 29, 25],
                    [21, 31, 32, 34, 26, 29, 25, 39, 25],
                    [35, 29, 28, 38, 36, 29, 25, 30, 24],
                    [26, 22, 35, 22, 31, 24, 33, 28, 24],
                    [17, 34, 30, 30, 28, 30, 26, 26, 24],
                    [25, 27, 33, 27, 26, 24, 26, 22, 27],
                    [31, 33, 29, 26, 30, 34, 22, 29, 24],
                    [24, 25, 33, 29, 28, 29, 24, 23, 20]]
plt.imshow(count_array_28nm, cmap="cmr.amber")
plt.savefig(graphical.gui_get_path(is_file=False)/"count_map_28nm.png")
